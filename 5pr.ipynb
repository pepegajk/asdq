# %% [markdown]
# Практическая работа №5

# %% [markdown]
# Цель: провести базовый анализ датасета используя такие методы как "head", "shape", "columns", "unique", "sort_values", "drop", "replace", "drop_duplicates", "info", "describe", "loc", "to_csv"

# %%
import pandas as pd 
import numpy as np

dota2 = pd.read_csv('Dota2_Heroes_by_MMR_Bracket.csv')
dota2.head()
# Out:
#            Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 0       Anti-Mage                11.16%               51.22%
# 1             Axe                17.36%               52.93%
# 2            Bane                 2.31%               47.96%
# 3     Bloodseeker                 4.71%               48.53%
# 4  Crystal Maiden                13.83%               50.54%
#
#   (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 0                   9.65%                 51.53%                   7.91%
# 1                  16.18%                 51.01%                  14.50%
# 2                   2.38%                 49.05%                   2.71%
# 3                   3.28%                 48.43%                   2.77%
# 4                  10.69%                 48.85%                   8.37%
#
#   (3K-4K MMR) WinRate(%) (4K-5K MMR) PickRate(%) (4K-5K MMR) WinRate(%)  \
# 0                 51.77%                   6.48%                 51.03%
# ...

# %% [markdown]
# 1.Я вывел начальные данные из своего датасета

# %%
dota2.shape
# Out:
# (124, 22)

# %% [markdown]
# 2. Я вывел размерность массива через метод Shape

# %%
dota2.columns
# Out:
# Index(['Heroes', '(<2K MMR) PickRate(%)', '(<2K MMR) WinRate(%)',
#        '(2K-3K MMR) PickRate(%)', '(2K-3K MMR) WinRate(%)',
#        '(3K-4K MMR) PickRate(%)', '(3K-4K MMR) WinRate(%)',
#        '(4K-5K MMR) PickRate(%)', '(4K-5K MMR) WinRate(%)',
#        '(>5K MMR) PickRate(%)', '(>5K MMR) WinRate(%)', 'Heroes.1',
#        '(>2K MMR) KDA Ratio', '(>2K MMR) Avg Match', '(2K-3K MMR) KDA Ratio',
#        '(2K-3K) Avg Match', '(3K-4K MMR) KDA Ratio', '(3K-4K MMR) Avg Match',
#        '(4K-5K MMR) KDA Ratio', '(4K-5K MMR) Avg Match', '(<5K MMR) KDA Ratio',
#        '(<5K MMR) Avg Match'],
#       dtype='object')

# %% [markdown]
# 3.Я вывел все названия колонок из своего датасета

# %%
dota2 ['(<2K MMR) PickRate(%)'].unique()
# Out:
# array(['11.16%', '17.36%', '2.31%', '4.71%', '13.83%', '13.02%', '12.59%',
#        '11.23%', '6.27%', '7.50%', '15.70%', '8.39%', '4.41%', '29.72%',
#        '3.52%', '5.65%', '5.61%', '6.54%', '3.47%', '8.78%', '8.83%',
#        '10.88%', '9.80%', '12.12%', '19.47%', '14.78%', '10.38%', '5.10%',
#        '25.51%', '8.95%', '8.30%', '4.07%', '7.65%', '19.34%', '15.78%',
#        '8.82%', '1.11%', '5.64%', '6.73%', '12.41%', '14.24%', '2.57%',
#        '21.64%', '7.63%', '7.36%', '7.43%', '7.39%', '3.36%', '14.21%',
#        '3.21%', '1.61%', '19.77%', '9.04%', '1.50%', '6.92%', '3.30%',
#        '6.05%', '6.70%', '3.69%', '1.12%', '8.02%', '10.53%', '12.35%',
#        '0.85%', '1.03%', '15.72%', '8.34%', '2.73%', '6.51%', '24.72%',
#        '3.65%', '3.16%', '19.28%', '12.38%', '7.12%', '0.93%', '1.77%',
#        '1.73%', '3.70%', '16.60%', '2.43%', '9.74%', '14.35%', '10.18%',
#        '12.50%', '5.79%', '5.20%', '2.68%', '4.28%', '1.08%', '13.36%',
# ...

# %% [markdown]
# 4. Я вывел все уникальные данные а именно в стобце '(<2K MMR) PickRate(%)' c помощью метода Unique

# %%
dota2.sort_values(by = 'Heroes')
# Out:
#                  Heroes (<2K MMR) PickRate(%) (<2K MMR) WinRate(%)  \
# 100             Abaddon                 3.21%               53.86%
# 71            Alchemist                 3.16%               45.13%
# 66   Ancient Apparition                 8.34%               52.46%
# 0             Anti-Mage                11.16%               51.22%
# 111          Arc Warden                 6.71%               53.87%
# ..                  ...                   ...                  ...
# 20           Windranger                 8.83%               47.21%
# 110       Winter Wyvern                 2.24%               48.03%
# 28         Witch Doctor                25.51%               56.80%
# 40          Wraith King                14.24%               56.65%
# 21                 Zeus                10.88%               53.32%
#
#     (2K-3K MMR) PickRate(%) (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%)  \
# 100                   3.85%                 54.41%                   4.14%
# ...

# %% [markdown]
# 5. Я отсортировал все данные по героеям в алфовитном порядке с помощью метода sort_values

# %%
dota2.drop(columns=['(<2K MMR) WinRate(%)'], inplace=True)

# %% [markdown]
# 6.Я удалил колонку "(<2K MMR) WinRate(%)" с помощью метода drop

# %%
dota2 = dota2.replace({'(2K-3K MMR) PickRate(%)': np.nan}, 'Unknown')
dota2
# Out:
#              Heroes (<2K MMR) PickRate(%) (2K-3K MMR) PickRate(%)  \
# 0         Anti-Mage                11.16%                   9.65%
# 1               Axe                17.36%                  16.18%
# 2              Bane                 2.31%                   2.38%
# 3       Bloodseeker                 4.71%                   3.28%
# 4    Crystal Maiden                13.83%                  10.69%
# ..              ...                   ...                     ...
# 119            Mars                 2.40%                   2.93%
# 120     Dawnbreaker                 6.88%                   8.54%
# 121           Marci                 3.70%                   3.75%
# 122    Primal Beast                 6.40%                   7.89%
# 123          Muerta                12.27%                  14.74%
#
#     (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%) (3K-4K MMR) WinRate(%)  \
# 0                   51.53%                   7.91%                 51.77%
# ...

# %% [markdown]
# 7. Я заменил конкретные данные в колонке '(2K-3K MMR) PickRate(%)' на Unknown с помощью метода replace

# %%
dota2 =dota2.drop_duplicates()
dota2
# Out:
#              Heroes (<2K MMR) PickRate(%) (2K-3K MMR) PickRate(%)  \
# 0         Anti-Mage                11.16%                   9.65%
# 1               Axe                17.36%                  16.18%
# 2              Bane                 2.31%                   2.38%
# 3       Bloodseeker                 4.71%                   3.28%
# 4    Crystal Maiden                13.83%                  10.69%
# ..              ...                   ...                     ...
# 119            Mars                 2.40%                   2.93%
# 120     Dawnbreaker                 6.88%                   8.54%
# 121           Marci                 3.70%                   3.75%
# 122    Primal Beast                 6.40%                   7.89%
# 123          Muerta                12.27%                  14.74%
#
#     (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%) (3K-4K MMR) WinRate(%)  \
# 0                   51.53%                   7.91%                 51.77%
# ...

# %% [markdown]
# 8. Я удалил дубликаты в датасете с помощью метода drop_duplicates()

# %%
dota2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Heroes                   124 non-null    object
#  1   (<2K MMR) PickRate(%)    124 non-null    object
#  2   (2K-3K MMR) PickRate(%)  124 non-null    object
#  3   (2K-3K MMR) WinRate(%)   124 non-null    object
#  4   (3K-4K MMR) PickRate(%)  124 non-null    object
#  5   (3K-4K MMR) WinRate(%)   124 non-null    object
#  6   (4K-5K MMR) PickRate(%)  124 non-null    object
#  7   (4K-5K MMR) WinRate(%)   124 non-null    object
#  8   (>5K MMR) PickRate(%)    124 non-null    object
#  9   (>5K MMR) WinRate(%)     124 non-null    object
#  10  Heroes.1                 124 non-null    object
#  11  (>2K MMR) KDA Ratio      124 non-null    float64
#  12  (>2K MMR) Avg Match      124 non-null    object
#  13  (2K-3K MMR) KDA Ratio    124 non-null    float64
# ...

# %% [markdown]
# 9. Я проанализировал свой датасет с помощью метода info

# %%
dota2.describe()
# Out:
#        (>2K MMR) KDA Ratio  (2K-3K MMR) KDA Ratio  (3K-4K MMR) KDA Ratio  \
# count           124.000000             124.000000             124.000000
# mean              2.723790               2.880161               2.939839
# std               0.408277               0.474124               0.504660
# min               1.990000               2.010000               2.030000
# 25%               2.470000               2.560000               2.590000
# 50%               2.675000               2.785000               2.870000
# 75%               2.960000               3.152500               3.240000
# max               4.460000               4.730000               4.860000
#
#        (4K-5K MMR) KDA Ratio  (<5K MMR) KDA Ratio
# count             124.000000           124.000000
# mean                2.969758             2.983629
# std                 0.526736             0.560948
# min                 2.010000             1.980000
# 25%                 2.597500             2.582500
# ...

# %% [markdown]
# 10.Я c помощью метода describe провел статистический числвой анализ :
# - count - количество непустых значений в столбцах - (>2K MMR) KDA Ratio	(2K-3K MMR) KDA Ratio	(3K-4K MMR) KDA Ratio	(4K-5K MMR) KDA Ratio	(<5K MMR) KDA Ratio
# - mean - среднее арифметическое значение (сумма всех значений столбца, деленная на количество этих значений)
# - std - стандартное отклонение относительно среднего значения, в столбце height оно небольшое -  34,7, следовательно разброс по данным небольшой, а вот в столбце mass отклонение равно 169,4 - разброс по данным существенно больше
# - min показывает минимальное значение в столбце
# - max аналогично показывает максимальное значение в столбце
# - 25% - первый квартиль (нижний) - значение разделяет самые низкие 25% данных
# - 50% - медиана - значение разделяет данные пополам
# - 75% - третий квартиль (верхний) - значение разделяет самые низкие 75% данных

# %%
dota21 = dota2.loc[[0, 1, 2 ,3, 4, 5 ],['(3K-4K MMR) KDA Ratio', '(4K-5K MMR) KDA Ratio', '(<5K MMR) KDA Ratio']]
dota21
# Out:
#    (3K-4K MMR) KDA Ratio  (4K-5K MMR) KDA Ratio  (<5K MMR) KDA Ratio
# 0                   3.42                   3.41                 3.45
# 1                   2.56                   2.57                 2.56
# 2                   2.43                   2.39                 2.29
# 3                   3.13                   3.23                 3.41
# 4                   2.17                   2.17                 2.15
# 5                   3.02                   3.02                 2.94

# %% [markdown]
# 11. Я провел выборку данных по строкам и столбцам с помощью метода loc а именно вывел первые шесть ячейки с данными в таких колонках как: "(3K-4K MMR) KDA Ratio", "(4K-5K MMR) KDA Ratio", "(<5K MMR) KDA Ratio"

# %%
dota2.to_csv("New_dota2.csv", index=True)
dota2
# Out:
#              Heroes (<2K MMR) PickRate(%) (2K-3K MMR) PickRate(%)  \
# 0         Anti-Mage                11.16%                   9.65%
# 1               Axe                17.36%                  16.18%
# 2              Bane                 2.31%                   2.38%
# 3       Bloodseeker                 4.71%                   3.28%
# 4    Crystal Maiden                13.83%                  10.69%
# ..              ...                   ...                     ...
# 119            Mars                 2.40%                   2.93%
# 120     Dawnbreaker                 6.88%                   8.54%
# 121           Marci                 3.70%                   3.75%
# 122    Primal Beast                 6.40%                   7.89%
# 123          Muerta                12.27%                  14.74%
#
#     (2K-3K MMR) WinRate(%) (3K-4K MMR) PickRate(%) (3K-4K MMR) WinRate(%)  \
# 0                   51.53%                   7.91%                 51.77%
# ...

# %% [markdown]
#  12. Я сохранил новый датасет при помощи метода to_csv

# %% [markdown]
# Вывод: в ходе практичсекой работы был произведен базовый анализ датасета при помощи таких методов как:  "head", "shape", "columns", "unique", "sort_values", "drop", "replace", "drop_duplicates", "info", "describe", "loc", "to_csv"
